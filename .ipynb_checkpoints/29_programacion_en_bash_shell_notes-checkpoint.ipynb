# %% [markdown]
# ### <a name='index'></a> Index
#
# ### [Componentes de Linux, Tipos de Shell y Comandos de informació](#mark_01)
#
# ### [Conocer los comando con ``man <comando>``, ``info <comando>``](#mark_02)
#
# ### [Setting "vimrc" archivo de configuración](#mark_03)
#
# ### [Creando el primer archivo "vim" para ejecutar](#mark_04)
#
# ### [Modificando los permisos](#mark_05)
#
# ### [Declaración de Variables y su Alcance en Bash Shell](#mark_06)
#
# ### [Tipo de Operadores](#mark_07)
#
# ### [Ejecutar Script con Argumentos](#mark_08)
#
# ### [Cómo utilizar "comandos" en variables](#mark_09)
#
# ### [Debug de Script](#mark_10)
#
# ### [Capturar información usuario](#mark_11)
#
# ### [leer usando "read"](#mark_12)
#
# ### [Validaciones con RegEx](#mark_13)
#
# ### [Validaciones con "Read"](#mark_14)
#
# ### [Paso de parámetros y opciones](#mark_15)
#
# ### [Descargar información de Internet](#mark_16)
#
# ### [Sentencias If/Else](#mark_17)
#
# ### [If anidados](#mark_18)
#
# ### [Expresiones Condicionales](#mark_19)
#
# ### [Sentecia "case"](#mark_20)
#
# ### [Arreglos](#mark_21)
#
# ### [for loop](#mark_22)
#
# ### [while loop](#mark_23)
#
# ### [loops anidados](#mark_24)
#
# ### [break y continue](#mark_25)
#
# ### [Menú de opciones](#mark_26)
#
# ### [Archivos y Directorios](#mark_27)
#
# ### [Escribir dentro de archivos](#mark_28)
#
# ### [Leer Archivos](#mark_29)
#
# ### [Operaciones en Archivos](#mark_30)
#
# ### [Empaquetamiento TAR, y compresión con GZIP y PBZIP 2](#mark_31)
#
# ### [Respaldo Empaquetado con clave](#mark_32)
#
# ### [rsync Transferir información empaquetad en la red](#mark_33)
#
# ### [Menu y opciones con funciones y utilidades de Postgres](#mark_34)
#
# ### [](#mark_0)
#
# ### [](#mark_0)
#
# ### [](#mark_0)
#
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_01'></a> Componentes de Linux, Tipos de Shell y Comandos de informació,
# ### [Index](#index)
#
#
# - Kernel (el primer componente y el más importante):
#     - Núcleo del sistema operativo en el cual se gestionan todos los recursos de hardware, como son la memoría, el procesamiento y todo lo que tiene que ver con periféricos conectados a su computador, además aquí será donde se ejecuten las aplicaciones.
#
# - Shell:
#     - Intérprete, un programa que tiene una interfaz de usuario que permite ejecutar las aplicaciones en un lenguaje de alto nivel y procesarlos en un lenguaje de bajo nivel, para poder manipular y controlar todo lo que tiene que ver con una aplicación o programa.
#
# - Aplicaciones.
#     - Aplicaciones que interactúan con el usuario, estas aplicaciones ejecutaran comando, o puede ejecutar acciones en el núcleo Kernel.
#
# ![](img_01.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# **Tipos de Shells**
#
# • SH • KSH • CSH • BASH
#
# 1. SH: También conocida como Shell Bourne, es la primera shell creada para un sistema operativo linux, se puede utilizar actualmente, pero se perderían funcionalidades como autocompletar archivos o el historial de comandos.
#
# 2. KSH: Desarrollada por el programador David Korn. Intenta combinar las características de la CSH, TCSH y SH.
#
# 3. CSH: En una shell diseñada para que los usuarios puedan escribir programas de scripting de shell con una sintaxis muy simiar a la de C. En muchas sistemas como Red Hat, csh es tcsh, una versión mejorada de csh.
#
# 4. BASH: También conocida como Shell Bourne-Again, es una versión actualizada de SH creada por la Free Software Fundation. Es una de la shell más utilizada y conocida en el mundo. Incorpora alguna de las funcionalidades más avanzadas de KSH, CSH, SH y TCSH. Una de la funcionalidades más destacables de esta shell es la opción de ejecutar múltiples programas en segundo plano a la vez.
#
# 5. ZSH: Potente intérprete de comandos que puede funcionar como shell interactiva y como intérprete de lenguaje de scripting. aún siendo compatible con Bash.
#
# Más info: https://www.taringa.net/+linux/tipos-de-shells_wpzwm

# %% [markdown]
# ### <a name='mark_02'></a> Conocer los comando con ``man <comando>``, ``info <comando>``
# ### [Index](#index)
#
# - `man <comando>` --> Nos muestra el manual, con la información escencial.
# - `info <comando>`--> Muestra en profundidad información sobre el comando.

# %% [markdown]
# ### <a name='mark_03'></a> Setting "vimrc" archivo de configuración.
# ### [Index](#index)
#
# - Seteamos un archivo en "vim" (configuraciones para el editor vim).
# 1. Vamos al directorio raíz --> `cd $home`
#
# 2. Creamos el archivo "vimrc" --> `vim .vimrc` (si no existia, será creado)
#
# 3. dentro de "vimrc" setamos algunos características.
#
#     - set showmode --> mostrar lo que vamos haciendo en las operaciones.
#     - set autoindent --> identación
#     - set tabstop=4 --> cada cuantos espacios se va a identar.
#     - set expandtab --> salto de línea identa según jerarquía.
#     - syntax on --> colorear los diferentes comandos.
#
# ```bash
# set showmode
# set autoindent
# set tabstop=4
# set expandtab
# syntax on
#
# ```
# 4. Para salir, usamos "esc" luego escribo ":wq" o ":x" (guarda los cambios y cierra vim)

# %% [markdown]
# ### <a name='mark_04'></a> Creando el primer archivo "vim" para ejecutar.
# ### [Index](#index)
#
# - vamos a la carpeta donde trabajaremos, en este caso creamos la carpeta "shell_course" y dentro de ella el archivo "01_utility_postgres.sh"
#
# - Como vemos en la siguiente imagen el archivo se crea con un primer comentario `# !/bin/bash/` para que sea reconocido al momento de ejecutarlo, pero cuando revisamos los permisos, el archivo no tiene permiso de ejecución.
#
# ![](img_02.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_05'></a> Modificando los permisos y ejecutando.
# ### [Index](#index)
#
# - cambiamos los permisos usando el exadecimal "764"
#
#
# ![](img_03.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_05.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ahora podemos ejecutar el archivo de dos forma diferentes:
#
# ![](img_04.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ### Nota importante!!!
#
# - Al momento de crear un archivo ejecutable, es importante que el nombre de este no sea el mismo de algún archivo ya existente en el sistema, por lo cual debemos vericar esto utilizando el comando `type nombre_archivo`, esto mostrará si ese nombre fue encontrado como un archivo del sistema, si es así debemos cambiar el nombre del archivo, de lo contrario simplemente mostrará un `not found`
#
# - En ciertas ocasiones, un comando no tiene una definición sino varias; para poder estar al tanto de esto, podemos ejecutar el comando con la bandera -a y así nos mostrará todas las definiciones del comando.
#
# - Si por otro lado, deseamos también ver el tipo de archivo (pues, podemos tener quizás dos archivos con nombres iguales, pero con diferente connotación), podemos utilizar la bandera -t.
#
# Ejemplos:
#
# - type ls
# - type cd
# - type -a ls
# - type -t cd

# %% [markdown]
# ### <a name='mark_06'></a> Declaración de Variables y su Alcance en Bash Shell.
# ### [Index](#index)
#
# 1. Variables de entorno.
# 2. Documentación útil:
#
#        https://learn.microsoft.com/es-es/windows/wsl/setup/environment
#
#        https://www.youtube.com/watch?v=KaMce18aSLA
#
# - Linux, donde se encuentran estas variables?, ejecutamos `vim /etc/profile`
#
# ![](img_06.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Si queremos modificar este archivo debemos ingresar como Super Usuario "sudo", ejecutando `sudo vim /ete/profile`
#
# ### Recordar que para modificar el archivo tenemos que tipear "i" que habilita a "insertar" nuevo texto.
#
# - Como esta variable es a nivel de Sistema Operativo, todos los usuarions independientemente de su cuanta pueden revisar el valor de esta variable.
#
# - Crearemos una variable llamada `COURSE_NAME=Programacion bash`, esta variable debe ser exportada `export COURSE_NAME`
#
# ![](img_07.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# Ayudan a obtener infromacion del sistema, almacenar informacion temporal y modificar su informacion. Existen 2 tipos:
#
#     - Variables Globales: Son visibles desde el shell que lo creo o desde cuaquier hijo de esa shell.
#
#     - Variables Locales: Son visibles solo desde el shell que la creo.
#
#     - Variable Persistente: Para crear una de estas es necesario introducirla en el archivo /etc/profile pero en el caso de los derivados debian si revisamos un poco el script nos damos cuenta que llama a otro archivo llamado /etc/bash.bashrc en el cual podemos crear las variables de entorno persistentes. Por eso no funciona llamar la variable declarada en /etc/profile desde un shell
#
# 2. Variables de usuario Son las variables que se utilizan a nivel de programa, corren dentro de un script como en cualquier programa de computadora C, C++ o Java.
#
# - Creamos un nuevo archivo "02_variables.sh" para guardar las variables de usuario a nivel del programa, con lo cual solo existiran en este programa.
#
# ![](img_08.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ### Recordar que el archivo no tiene permisos de ejecución
#
# ![](img_09.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ### Exportando variable para ser usada en otro script de otro archivo.
#
# - Primero realizamos una copia de "02_variables.sh" por cuestiones de comodidad, ya que este archivo tiene los permisos de ejecución `cp 02_variables.sh 02_variables_export.sh`
#
# - En este nuevo archivo `02_variables_export.sh` borramos las variables nombre, apellido y edad, solo dejamos la función "echo".
#
# ![](img_10.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Para borrar la línea entera, "esc" y dos veces la letra "d", guardamos y salimos.
#
# - Ahora modificamos el archivo que exportará la variable `02_variablers.sh`.
#
# ![](img_11.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutamos...
#
# ![](img_12.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
#
#     - Variable global: Se puede usar desde otro script siempre y cuando sea llamado desde el script que contiene la variable.
#
#     - Variable local:_ Solo tiene alcance en el script que la creo.

# %% [markdown]
# ### <a name='mark_07'></a> Tipos de Operadores.
# ### [Index](#index)
#
# ### Algunos tips para escribir en "vim".
#
# - "esc" luego "u" --> deshacer los cambios.
# - si queremos copiar 3 lineas "esc" luego "yy" más la letra "p" para copiar.
#
# ### Algunos operadores:
#
# ![](img_13.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando:
#
# ![](img_14.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_08'></a> Ejecutar Script con Argumentos.
# ### [Index](#index)
#
# - Utilizamos `$1`, `$2`, para captar el primer y segundo argumento pasados al momento de ejecutar el script, si tenemos más de 9 argumentos debemos utilizar las llaves, `${10}`
# - `$#` --> recuperamos el total de los argumentos pasados.
# - `$*` --> recuperamos todos los argumentos
# - Si usamos `$0`, esto imprime el nombre del archivo, para este caso `./04_argumentos.sh`
# ![](img_15.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutamso el script:
#
# - Es importante cuando pasamos una cadena utilizar las "" para que no se interprete como varios argumentos.
#
# ![](img_16.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_09'></a> Cómo utilizar "comandos" en variables.
# ### [Index](#index)
#
# - los dos formatos utilizados para asignar comandos a variables, backsticks, y `$(mi_comando)`
#
# ![](img_17.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
# - Ejecutando...
#
# ![](img_18.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_10'></a> Debug de Script.
# ### [Index](#index)
#
# - "-v" Utilizado para ver el resultado detallado de nuestro script, evaluando línea de línea.
#
# ![](img_19.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - "-x" Utilizado para ver/desplegar la información de los comandos que son utilizados, capturando el comando y sus salidas (cuando es un comando, cuando una salida o entrada, etc, marcado con un símbolo "+").
#
# ![](img_20.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_11'></a> Capturar información usuario.
# ### [Index](#index)
#
# - Utilizaremos `echo`, `read`, y `$REPLY`
#
# ![](img_21.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando.
#
# ![](img_22.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_12'></a> leer usando "read".
# ### [Index](#index)
#
# - No necesitaremos `echo`, `$REPLY`, usaremos `read` con el flag `-p`
#
# ![](img_23.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando:
#
# ![](img_24.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_13'></a> Validaciones con RegEx.
# ### [Index](#index)
#
# - Realizará un programa que valida la siguiente información:
#
#     - Número de Identificación de un tamaño de 10 números. Ejemplo: 1717836520
#     - País de Origen denotado por dos letras en un rango específico. Ejemplo: EC, CO, US
#     - Fecha de Nacimiento en el formato yyyy-MM-DD. Ejemplo: 2018-12-22
#
# ![](img_25.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecución:
#
# ![](img_26.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_14'></a> Validaciones con "Read".
# ### [Index](#index)
#
# - `read -s` -> Oculta la información entrante por propio usuario.
#
# - `read -n[1,2,3,4...]` -> Mantiene la linea de ejecución, la misma linea en la que estamos hasta que llegue al numero de carácteres definido.
#
# - `read -p` -> Indica que hay que dejar la informacion ingresada en la variable siguiente.
#
# ![](img_27.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando
#
# ![](img_28.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_15'></a> Paso de parámetros y opciones.
# ### [Index](#index)
#
# - Options(Opciones).
#     - este argumento modifica el comportamiento del comando, pues lo utiliza ya sea para saber que se va a proceder, de hecho estos argumentos fueron los primeros que utilizamos desde el inicio por ejemplo al "enlistar" el contenido del directorio actual, incluso aquello archivos ocultos `ls -a`.
#
#     - La a en este comando es un argumento tipo opcion, y como resultado modifico su comportamiento y nos otorgo un output distinto, las opciones se destacan por tener el prefijo -.
#
# Params (Parametros). Estos argumentos son datos que nuestro comando utilizara o que alguna opcion utilizara, en su proceso, no modifican el comportamiento.
# - Tenemos que tener en cuenta que : shift lo que hace es eliminar `$1` y pasa `$2` a ser `$1`, la siguiente vez, elimina `$2` y pasa `$3` a `$1`, y así sucesivamente Y también tenemos que tener en cuenta que `[ -n "$1" ]` el `-n` implica que es cierto mientras `$1` no sea ni vacío ni nulo, es decir mientras exista y sea distinto de vacío.
#
# ![](img_29.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecución:
#
# ![](img_30.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_16'></a> Descargar información de Internet.
# ### [Index](#index)
#
# - utilizamos el comando `wget`
#
# ![](img_32.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Se ejecuta normalmente con `./nombre_archivo.sh`

# %% [markdown]
# ### <a name='mark_17'></a> Sentencias If/Else.
# ### [Index](#index)
#
#
# ![](img_33.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - OPERADORES RELACIONALES
#     - `-eq`: is equal to
#     - `-ne`: is not equal to
#     - `-gt`: is greater than
#     - `-ge`: is greater than or equal to
#     - `-lt`: is less than
#     - `-le`: is less than or equal to
#
# - Observar que se pueden utilizar diferentes sintaxis para el ej "(())", "[]" "[[]]", tener en cuenta el bloque if se cierra con "fi"
#
#
# ![](img_34.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando...
#
# ![](img_35.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Si queremos usar "AND --> &&" u "OR --> ||"
#
# ![](img_36.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ### Nota Muy Importante!!!
# - Fuente https://stackoverflow.com/questions/13542832/difference-between-single-and-double-square-brackets-in-bash/31366734#31366734:
#
# Behavior differences
#
# Tested in Bash 4.3.11:
#
# - POSIX vs Bash extension:
#
#     - [ is POSIX
#     - [[ is a Bash extension inspired from Korn shell
#
# - regular command vs magic
#
#     - [ is just a regular command with a weird name.
#
#     - ] is just the last argument of [.
#
# Ubuntu 16.04 actually has an executable for it at /usr/bin/[ provided by coreutils, but the bash built-in version takes precedence.
#
# Nothing is altered in the way that Bash parses the command.
#
# In particular, < is redirection, && and || concatenate multiple commands, ( ) generates subshells unless escaped by \, and word expansion happens as usual.
#
#     - [[ X ]] is a single construct that makes X be parsed magically. <, &&, || and () are treated specially, and word splitting rules are different.
#
# There are also further differences like = and =~.
#
# In Bashese: [ is a built-in command, and [[ is a keyword: https://askubuntu.com/questions/445749/whats-the-difference-between-shell-builtin-and-shell-keyword
#
# - <
#
#     - [[ a < b ]]: lexicographical comparison
#     - [ a \< b ]: Same as above. \ required or else does redirection like for any other command. Bash extension.
#     - expr `x"$x"\< x"$y" > /dev/null or [ "$(expr x"$x" \< x"$y")" = 1 ]` : POSIX equivalents, see: How to test strings for lexicographic less than or equal in Bash?
# && and ||
#
#     - [[ a = a && b = b ]]: true, logical and
#     - [ a = a && b = b ]: syntax error, && parsed as an AND command separator cmd1 && cmd2
#     - [ a = a ] && [ b = b ]: POSIX reliable equivalent
#     - [ a = a -a b = b ]: almost equivalent, but deprecated by POSIX because it is insane and fails for some values of a or b like ! or ( which would be interpreted as logical operations
# (
#
#     - [[ (a = a || a = b) && a = b ]]: false. Without ( ), would be true because [[ && ]] has greater precedence than [[ || ]]
#     - [ ( a = a ) ]: syntax error, () is interpreted as a subshell
#     - [ \( a = a -o a = b \) -a a = b ]: equivalent, but (), -a, and -o are deprecated by POSIX. Without \( \) would be true because -a has greater precedence than -o
#     - { [ a = a ] || [ a = b ]; } && [ a = b ] non-deprecated POSIX equivalent. In this particular case however, we could have written just: [ a = a ] || [ a = b ] && [ a = b ] because the || and && shell operators have equal precedence unlike [[ || ]] and [[ && ]] and -o, -a and [
# word splitting and filename generation upon expansions (split+glob)
#
# `x='a b'; [[ $x = 'a b' ]]`: true, quotes not needed
# `x='a b'; [ $x = 'a b' ]`: syntax error, expands to [ a b = 'a b' ]
# `x='*'; [ $x = 'a b' ]`: syntax error if there's more than one file in the current directory.
# `x='a b'; [ "$x" = 'a b' ]`: POSIX equivalent
# - =
#
#     - [[ ab = a? ]]: true, because it does pattern matching (* ? [ are magic). Does not glob expand to files in current directory.
#     - [ ab = a? ]: a? glob expands. So may be true or false depending on the files in the current directory.
#     - [ ab = a\? ]: false, not glob expansion
# = and == are the same in both [ and [[, but == is a Bash extension.
# case ab in (a?) echo match; esac: POSIX equivalent
#     - [[ ab =~ 'ab?' ]]: false, loses magic with '' in Bash 3.2 and above and provided compatibility to bash 3.1 is not enabled (like with BASH_COMPAT=3.1)
#     - [[ ab? =~ 'ab?' ]]: true
# - =~
#
#     - [[ ab =~ ab? ]]: true, POSIX extended regular expression match, ? does not glob expand
#     - [ a =~ a ]: syntax error. No bash equivalent.
# printf 'ab\n' | grep -Eq 'ab?': POSIX equivalent (single line data only)
# awk 'BEGIN{exit !(ARGV[1] ~ ARGV[2])}' ab 'ab?': POSIX equivalent.
# Recommendation: always use []
#
# There are POSIX equivalents for every [[ ]] construct I've seen.
#
# If you use [[ ]] you:
#
# lose portability
# force the reader to learn the intricacies of another bash extension. [ is just a regular command with a weird name, no special semantics are involved.

# %% [markdown]
# ### <a name='mark_18'></a> If anidados.
# ### [Index](#index)
#
# ![](img_37.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_38.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecución...
#
# ![](img_39.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_19'></a> Expresiones Condicionales.
# ### [Index](#index)
#
#
# ![](img_40.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando...
#
# ![](img_41.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - OTROS COMPARADORES INTERESANTES
#     - `-d` te permitirá saber si es un directorio y si existe
#     - `-e` lo mismo que en el caso anterior pero para archivos
#     - `-r` en este caso te permite saber si el archivo tiene permiso de lectura
#     - `-s` con esta opción puedes saber si el tamaño del archivo es mayor que cero. Es decir, que no se trata de un archivo vacío
#     - `-w` te permitirá identificar si el archivo tienen permisos de escritura
#     - `-x` lo mismo que en el caso anterior pero para el caso de permisos de ejecución.
#
# - Corchetes simples [  ] vs Corchetes Dobles [[  ]]
#
# Los dobles corchetes resultan ser una mejora respecto a los simples. Así, las diferencias entre uno y otro son las siguientes:
#
#     - No tienes que utilizar las comillas con las variables, los dobles corchetes trabajan perfectamente con los espacios. Así `[ -f "$file" ]` es equivalente a `[[ -f $file ]]`.
#
# Con [[ puedes utilizar los operadores || y && , asi como < y >` para las comparaciones de cadena.
# Puedes utilizar el operador =~ para expresiones regulares, compo por ejemplo
#
# `[[ $respuesta =~ ^s(i)?$ ]]`
#
# También puedes utilizar comodines como por ejemplo en la expresión `[[ abc = a\* ]]`
#
# Es posible que te preguntes por la razón para seguir utilizando [ corchete simple en lugar de doble. La cuestión es por compatibilidad. Si utilizas Bash en diferentes equipos es posible que te encuentres alguna imcompatibilidad. Así que depende de ti y de donde lo vayas a utilizar.

# %% [markdown]
# ### <a name='mark_20'></a> Sentecia "case".
# ### [Index](#index)
#
#
# ![](img_42.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_43.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ### Observaciones "asec" es "case" al revez, marca el fin del bloque, "[c-d]", es un rango.
#
# - Ejecutando ...
#
# ![](img_44.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_21'></a> Arreglos.
# ### [Index](#index)
#
#
# ![](img_45.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando...
#
# ![](img_46.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_22'></a> for loop.
# ### [Index](#index)
#
#
# ![](img_48.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando...
#
# ![](img_49.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_50.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_51.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_23'></a> while loop .
# ### [Index](#index)
#
#
# ![](img_52.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_53.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando ...
#
# ![](img_54.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_24'></a> loops anidados.
# ### [Index](#index)
#
#
# ![](img_55.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_25'></a> Break y continue.
# ### [Index](#index)
#
# ![](img_56.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_57.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando ...
#
# ![](img_58.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_26'></a> Menú de opciones.
# ### [Index](#index)
#
# ![](img_59.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando ...
#
# ![](img_60.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_27'></a> Archivos y Directorios.
# ### [Index](#index)
#
# ![](img_61.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_62.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Ejecutando...
#
# ![](img_63.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_28'></a> Escribir dentro de archivos.
# ### [Index](#index)
#
# ![](img_64.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Escribiendo...
#
# ![](img_65.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_29'></a> Leer Archivos.
# ### [Index](#index)
#
# ![](img_66.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_67.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_30'></a> Operaciones en Archivos.
# ### [Index](#index)
#
# ![](img_68.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ### <a name='mark_31'></a> Empaquetamiento TAR, y compresión con GZIP y PBZIP 2.
# ### [Index](#index)
#
# 1. **tar:**
#    - "tar" es una herramienta para empaquetar uno o varios archivos y directorios en un solo archivo, comúnmente llamado "tarball". Aunque "tar" en sí mismo no realiza compresión, a menudo se usa junto con otras herramientas como "gzip" o "bzip2" para comprimir el archivo resultante.
#    - Ejemplo de empaquetamiento (sin compresión): `tar -cvf nuevo_archivo.tar directorio_a_convertir`
#    - Ejemplo de empaquetamiento y compresión con gzip todo en uno: `tar -czvf archivo.tar.gz directorio`
#
# - Este comando crea un archivo llamado "mi_directorio.tar.gz" que contiene todos los archivos y subdirectorios de "mi_directorio", y luego lo comprime con gzip. La opción -c crea un archivo, la opción -z indica que se debe usar gzip para la compresión, y la opción -f especifica el nombre del archivo resultante.
#
# ![](img_69.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# -Ejecución ....
#
# ![](img_70.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Confirmación ...
#
# ![](img_71.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# 2. **gzip:**
#    - "gzip" es una herramienta de compresión que se utiliza para comprimir archivos. A menudo se utiliza con archivos individuales y no para empaquetar directorios. Es rápido pero puede no comprimir tan eficientemente como otras opciones como "bzip2".
#    - Ejemplo de compresión: `gzip archivo`
#
# - La optimización de la compresión con `gzip` generalmente se centra en encontrar un equilibrio entre el nivel de compresión y el tiempo de ejecución. `gzip` ofrece opciones de nivel de compresión del 1 al 9, donde 1 es la compresión más rápida pero menos eficiente, y 9 es la compresión más lenta pero más eficiente.
#
# - Por defecto, `gzip` utiliza el nivel de compresión 6, que es un buen compromiso entre velocidad y eficiencia. Puedes especificar el nivel de compresión con la opción `-n`, por ejemplo:
#
# ```bash
# gzip -9 archivo.txt
# ```
#
# - Esto comprimirá "archivo.txt" con el nivel de compresión más alto (mejor compresión pero más lento).
#
# - Si la velocidad es más crítica y no estás tan preocupado por el tamaño del archivo comprimido, puedes optar por niveles más bajos, como `-1` para la compresión más rápida:
#
# ```bash
# gzip -1 archivo.txt
# ```
#
# ![](img_72.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Después de la ejecución ...
#
# ![](img_73.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# 3. **pbzip2:**
#    - "pbzip2" es una versión paralela del programa de compresión "bzip2". Mientras que "bzip2" utiliza un solo núcleo para la compresión, "pbzip2" está diseñado para aprovechar múltiples núcleos de procesador simultáneamente, lo que puede llevar a una compresión más rápida en sistemas con varios núcleos.
#    - Ejemplo de compresión con "pbzip2": `pbzip2 archivo`
#    - Solo puede comprimir de a un archivo, hay que usarlo en conjunto con "tar"
#    - En ocaciones pbzip2 no está insatalado con lo cual hay que correr `sudo apt-get intall pbzip2`
#
# ![](img_74.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Después de la ejecución ...
#
# ![](img_75.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# En resumen, "tar" se utiliza para empaquetar archivos y directorios en un solo archivo, mientras que "gzip" y "pbzip2" se utilizan para la compresión. "pbzip2" es una variante de "bzip2" que puede aprovechar múltiples núcleos para una compresión más rápida en sistemas con capacidad de procesamiento paralelo. A menudo, se combinan estas herramientas para crear archivos comprimidos y empaquetados.

# %% [markdown]
# ### <a name='mark_32'></a> Respaldo Empaquetado con clave.
# ### [Index](#index)
#
# - Es probable que no este installado => `sudo apt-get install zip`
# ![](img_76.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_78.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# -Ejecutando...
#
# ![](img_77.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Luego de la ejecución.
#
# ![](img_79.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# - Simplemente para descomprimir usamos `unzip nombre_archivo` y colocamos la clave.

# %% [markdown]
# ### <a name='mark_33'></a> rsync Transferir información empaquetad en la red.
# ### [Index](#index)
#
# ![](img_80.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ![](img_81.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ### No se ejecutó en mi caso, hay que seguir investigando!!!
#
# https://www.atareao.es/software-linux/sincronizacion-a-fondo-con-rsync/
#
# https://www.youtube.com/watch?v=qE77MbDnljA

# %% [markdown]
# ### <a name='mark_34'></a> Menú y opciones con funciones y utilidades de Postgres.
# ### [Index](#index)
#
# ![](img_82.png)
# **-------------------------------------------------------------------------------------------------------------------------------------------------**
#
# ```sh
# #!/bin/bash
# # Programa para ejemplificar el uso de un menu y sus opciones con sus funciones correspondientes.
# # Autor: LMM - mi_email@dominio.com
#
# opciones=0
# fecha_actual= date +%y%m%d
#
# #definimos cada funcion
# instalar_postgres () {
#         echo "verificarndo si ya existe instalación de postgres..."
#         verify_psql_instalation=$(which psql)
#
#         #$? devuelve el estado del ultimo comando ejecutado --> "0" ejecutado "1" no ejecutado (significa que no encontro nada)
#         if [ $? -eq 0 ]; then
#                 echo -e "\nPostgres ya se encuentra instalado en el equipo"
#         else
#                 read -s -p "ingrese contraseña sudo: " sudo_pass
#                 echo -e "\n"
#                 read -s -p "ingresar contraseña a utilizar en Postgres" postgres_pass
#                 echo -e "\n"
#                 read -s -p "re ingres la contraseña de Postgres" postgres_repass
#                 #validación de Postgres password
#                 if [ $postgres_pass == $postgres_repass ]; then
#                         echo -e "\nla contraseña de postgres fue validada"
#                 else
#                         echo -e "\nlas contraseñas de postgres no coinciden"
#                 fi
#                 #pasamos el password con echo (no lo pasa por pantalla) al comando sudo usadon el pipe "|", -S no muestra la contraseña
#                 echo "$sudo_pass" | sudo -S apt update
#                 #hacemos lo mismo pero para instalar Postgres (el paquete contrib contiene extensiones, herramientas o funciones adicionales), lo anterior es un update de apt.
#                 echo "$sudo_pass" | sudo -S apt-get install postgresql postgresql-contrib
#                 #realizamos la modificacion de la contraseña de postgres, -u --> user, -c --> ejecutamos un comando
#                 sudo -u postgres psql -c "ALTER USER postgres WITH PASSWORD '{$postgres_pass}';"
#                 #habilitar los servicios
#                 echo "$sudo_pass" | sudo -S systemctl enable postgresql.service
#                 echo "$sudo_pass" | sudo -S systemctl start postgresql.service
#         fi
#         #el usuario tiene que presionar ENTER para que la funcion continue.
#         read -n 1 -s -r -p "presione ENTER para continuar..."
# }
#
# desinstalar_postgres () {
#         read -s -p "ingresar contraseña sudo..." sudo_pass
#         echo -e "\n"
#         echo "$sudo_pass" | sudo -S systemctl stop postgresql.service
#         echo "$sudo_pass" | sudo -S apt-get -y --purge remove postgresql\*
#         echo "$sudo_pass" | sudo -S rm -r /etc/postgresql
#         echo "$sudo_pass" | sudo -S rm -r /etc/postgresql-common
#         echo "$sudo_pass" | sudo -S rm -r /var/lib/postgresql
#         echo "$sudo_pass" | sudo -S userdel -r postgres
#         echo "$sudo_pass" | sudo -S gruopdel postgresql
#         read -n 1 -s -r -p "presione ENTER para continuar..."
# }
#
# sacar_respaldo () {
#
#         echo "listando las bases de datos existentes..."
#         # \l lista las bases de datos existentes.
#         sudo -u postgres psql -c "\l"
#         read -p "elegir la base de datos a respaldar: " ddbb_respaldar
#         echo -e "\n"
#         read -p "dirección donde se hara el back-up: " dir_back_up
#         if [ -d "$dir_back_up" ]; then
#                 echo -e "\nestablecer permisos al directorio"
#                 read -s -p "ingrese contraseña de sudo:" sudo_pass
#                 echo "$sudo_pass" | sudo -S chmod 755 $dir_back_up
#                 echo -e "\nrealizando respaldo"
#                 sudo -u postgres pg_dump -Fc $ddbb_respaldar > "$dir_back_up/ddbb_respaldo_$fecha_actual.bak"
#                 echo -e "\nrespaldo creado con exito en $dir_back_up/ddbb_respaldo_$fecha_actual.bak"
#         else
#                 echo -e "\nel directorio no existe"
#         fi
#         read -n 1 -s -r -p "presione ENTER para continuar..."
# }
#
# restaurar_respaldo () {
#         echo -e "Listar los respaldos\n"
#         read -p "Ingresar el directorio donde están los respaldos:" respaldos_back_up
#         ls -lac $respaldos_back_up
#         read -p "elija el respaldo a restaurar:" respaldo_a_restaurar
#         echo -e "\n"
#         read -p "ingrese el nombre de la ddbb destino:" ddbb_destino
#         #verificar se la ddbb_destino existe
#         verify_ddbb= $(sudo -u postgres psql -lqt | cut-d \ | -f 1 | grep -wq $ddbb_destino)
#         if [ $? -eq 0 ]; then
#                 echo -e "\nrestaurando en la ddbb destino"
#         else
#                 sudo -u postgres psql -c "create database $ddbb_destino"
#         fi
#         if [ -f $respaldos_back_up/$respaldo_a_restaurar ]; then
#                 echo -e "\nreaturando respaldo..."
#                 sudo -u postgres pg_restore -Fc -d $ddbb_destino "$respaldos_back_up/$respaldo_a_restaurar"
#                 echo -e "\nlistar las bbdd"
#                 sudo -u postgres psql -c "\l"
#         else
#                 echo -e "\nel respaldo $respaldo_a_restaurar no existe"
#         fi
#         read -n 1 -s -r -p "presione ENTER para continuar..."
# }
#
# # while : loop infinito hasta obtener un parámetro de salida o sentencia de salida.
# while :
# do
#         #limpiar la pantalla
#         clear
#         #desplegamos menu de opciones
#         echo "__________________________________________"
#         echo "PGUTIL - Programa de Utilidades de Posgres"
#         echo "__________________________________________"
#         echo "             MENU - PRINCIPAL             "
#         echo "__________________________________________"
#         echo "1. Instalar Postgres"
#         echo "2. Desinstalar Postgres"
#         echo "3. Sacar un Respaldo"
#         echo "4. Restablecer Respaldo"
#         echo "5. Salir"
#         #Leer los datos del usuario.
#         read -n1 -p "Coloque una opcion [1-5]:" opciones
#         #Validando opciones, instalacion fake!!!
#         case $opciones in
#                 1)
#                         instalar_postgres
#                         #el programa duerme por 3 segundo
#                         sleep 3
#                         #;; para! ... como si estuviera instalando Postgres
#                         ;;
#                 2)
#                         desinstalar_postgres
#                         sleep 3
#                         ;;
#                 3)
#                         #solicitamos se carge un directorio para hacer back-up
#                         read -p "directorio back-up: " dir_back_up
#                         #pasamos la funcion y el argumento
#                         sacar_respaldo $dir_back_up
#                         sleep 3
#                         ;;
#                 4)
#                         #solicitamos el directorio donde se guardara.
#                         read -p "directorio respaldo: " dir_respaldo
#                         restaurar_respaldo $dir_respaldo
#                         sleep 3
#                         ;;
#                 5)
#                         echo -e "\nSaliendo del Programa....."
#                          #para romper la ejecucion
#                         exit 0
#                         ;;
#         esac
# done
# ```
